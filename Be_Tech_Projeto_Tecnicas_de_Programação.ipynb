# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaCarolNP/programming_techniques/blob/main/Be_Tech_Projeto_Tecnicas_de_Programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 📚 **Projeto - Módulo Técnicas de Programação**
#
# Be Tech by Braskem - Ada Tech
#
# Alunas: Ana Carolina Nazareth e Amanda Mirelly Mendes Frazão

# %% [markdown]
# # Tópicos:
#
#
# *   DataFrame e Pandas
# *   Manipulação de dados
# *   Criação de gráfico

# %% [markdown]
# Covid19 Dataset apresenta dados relacionados a vacinação e morte ao redor do mundo. A partir destes dados, foram elaboradas questões a serem respondidas utilizando o Pandas afim de apresentar resultados analíticos.

# %% [markdown]
# Importar a biblioteca pandas para a manipulação do dataset.

# %%
#Importar a biblioteca pandas para a manipulação do dataset:
import pandas as pd

# %%
#Importar a biblioteca Matplotlib para criação de gráficos:
import matplotlib.pyplot as plt

# %%
#Importar a base de dados para a manipulação:

covid_vaccinations_df = pd.read_csv(
    "https://raw.githubusercontent.com/AnaCarolNP/programming_techniques/main/COVID_VACCINATIONS.csv",
    sep=",",
    header=0)

covid_deaths_df = pd.read_csv(
    "https://raw.githubusercontent.com/AnaCarolNP/programming_techniques/main/COVID%20DEATHS.csv",
    sep=",",
    header=0)

# %%
#visualizando o dataframe com dados de vacinação
covid_vaccinations_df
# Out:
#        iso_code continent     location       date  total_tests  new_tests  \
# 0           AFG      Asia  Afghanistan   1/3/2020          NaN        NaN
# 1           AFG      Asia  Afghanistan   1/4/2020          NaN        NaN
# 2           AFG      Asia  Afghanistan   1/5/2020          NaN        NaN
# 3           AFG      Asia  Afghanistan   1/6/2020          NaN        NaN
# 4           AFG      Asia  Afghanistan   1/7/2020          NaN        NaN
# ...         ...       ...          ...        ...          ...        ...
# 302744      ZWE    Africa     Zimbabwe   4/8/2023          NaN        NaN
# 302745      ZWE    Africa     Zimbabwe   4/9/2023          NaN        NaN
# 302746      ZWE    Africa     Zimbabwe  4/10/2023          NaN        NaN
# 302747      ZWE    Africa     Zimbabwe  4/11/2023          NaN        NaN
# 302748      ZWE    Africa     Zimbabwe  4/12/2023          NaN        NaN
#
#         total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# ...

# %%
#visualizando o dataframe com dados de mortes
covid_deaths_df
# Out:
#       iso_code continent     location      date  population  total_cases  \
# 0          AFG      Asia  Afghanistan  1/3/2020    41128772          NaN
# 1          AFG      Asia  Afghanistan  1/4/2020    41128772          NaN
# 2          AFG      Asia  Afghanistan  1/5/2020    41128772          NaN
# 3          AFG      Asia  Afghanistan  1/6/2020    41128772          NaN
# 4          AFG      Asia  Afghanistan  1/7/2020    41128772          NaN
# ...        ...       ...          ...       ...         ...          ...
# 35564      BWA    Africa     Botswana  5/4/2022     2630300     306200.0
# 35565      BWA    Africa     Botswana  5/5/2022     2630300     306200.0
# 35566      BWA    Africa     Botswana  5/6/2022     2630300     306200.0
# 35567      BWA    Africa     Botswana  5/7/2022     2630300     306200.0
# 35568      BWA    Africa     Botswana  5/8/2022     2630300      30620.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# ...

# %% [markdown]
# ## 📈 Querys:

# %% [markdown]
# ### 1- Quantitativo de total de mortes por continente:

# %%
local_deaths_max_df = covid_deaths_df[['continent', 'total_deaths']].groupby('continent').agg('max').sort_values(by='total_deaths', ascending=False)

# %%
local_deaths_max_df
# Out:
#                total_deaths
# continent
# South America      130472.0
# Europe              34115.0
# Asia                29446.0
# Oceania             19906.0
# Africa               6881.0
# North America         833.0

# %% [markdown]
# ### 2 -Comparação entre total de mortes e total de vacinação por continente

# %%
local_vaccine_max_df = covid_vaccinations_df[['continent', 'total_vaccinations']].groupby('continent').agg('max').sort_values(by='total_vaccinations', ascending=False)

# %%
local_vaccine_max_df
# Out:
#                total_vaccinations
# continent
# Asia                 3.491077e+09
# North America        6.747119e+08
# South America        4.864364e+08
# Europe               1.922215e+08
# Africa               1.166069e+08
# Oceania              6.368165e+07

# %%
merged_df = pd.merge(local_vaccine_max_df, local_deaths_max_df, on='continent')

# %%
merged_df
# Out:
#                total_vaccinations  total_deaths
# continent
# Asia                 3.491077e+09       29446.0
# North America        6.747119e+08         833.0
# South America        4.864364e+08      130472.0
# Europe               1.922215e+08       34115.0
# Africa               1.166069e+08        6881.0
# Oceania              6.368165e+07       19906.0

# %% [markdown]
# Comparação dos resultados:

# %% [markdown]
# ### 3 - Os 10 países com maior número de casos por milhão de habitantes e os 10 países com maior número de mortes por milhão de habitantes. Um dado está relacionado a outro?

# %%
#Definir os 10 países com maior número de casos por milhão de habitantes.

# %%
#Manter apenas a última linha de cada país
covid_deaths_filter = covid_deaths_df.drop_duplicates(subset="location",
                                                      keep="last")

# %%
#Colocar em ordem decrescente por número de casos
cases_descending = covid_deaths_filter.sort_values(by="total_cases_per_million",
                                ascending=False)

# %%
#Mostrar os 10 países com maior número de casos por milhão de habitantes.
print(cases_descending.head(10)[
    ["location",
     "total_cases_per_million"]
    ])
# Out:
#               location  total_cases_per_million
# 65821           Cyprus               731762.140
# 234705      San Marino               708607.896
# 87287   Faeroe Islands               652484.139
# 39495           Brunei               633921.452
# 247794        Slovenia               633139.341
# 101654       Gibraltar               628882.700
# 165863      Martinique               624412.264
# 7175           Andorra               600415.816
# 133952          Jersey               599218.383
# 253779     South Korea               596691.651

# %%
#Definir os 10 países com maior número de mortes por milhão de habitantes.

# %%
deaths_descending = covid_deaths_filter.sort_values(by="total_deaths_per_million",
                                ascending=False)

# %%
#Mostrar os 10 países com maior número de mortes por milhão de habitantes.
print(cases_descending.head(10)[
    ["location",
     "total_deaths_per_million"]
    ])
# Out:
#               location  total_deaths_per_million
# 65821           Cyprus                  1505.569
# 234705      San Marino                  3650.935
# 87287   Faeroe Islands                   527.138
# 39495           Brunei                   340.756
# 247794        Slovenia                  4354.096
# 101654       Gibraltar                  3458.090
# 165863      Martinique                  2979.495
# 7175           Andorra                  1991.408
# 133952          Jersey                  1453.121
# 253779     South Korea                   662.578

# %%
#Nomeando as duas tabelas:

top_10_cases_milion = cases_descending.head(10)[
    ["location",
     "total_cases_per_million"]
    ]

top_10_deaths_milion = cases_descending.head(10)[
    ["location",
     "total_deaths_per_million"]
    ]

# %%
#Juntando as duas tabelas geradas
df_merged = pd.merge(top_10_cases_milion, top_10_deaths_milion, how='inner', on='location')

# %%
print(df_merged)
# Out:
#          location  total_cases_per_million  total_deaths_per_million
# 0          Cyprus               731762.140                  1505.569
# 1      San Marino               708607.896                  3650.935
# 2  Faeroe Islands               652484.139                   527.138
# 3          Brunei               633921.452                   340.756
# 4        Slovenia               633139.341                  4354.096
# 5       Gibraltar               628882.700                  3458.090
# 6      Martinique               624412.264                  2979.495
# 7         Andorra               600415.816                  1991.408
# 8          Jersey               599218.383                  1453.121
# 9     South Korea               596691.651                   662.578

# %% [markdown]
# É possível perceber que TODOS os 10 países com maior número de casos a cada um milhão de habitantes também foram os países com maior número de mortes a cada um milhão de habitantes. Correlação de 100%.

# %% [markdown]
# ### 4 - Qual continente foi mais afetado pelo Covid?

# %%
# Filtrar os dados pela última data de cada país
last_date = covid_deaths_df.drop_duplicates(
    subset="location",
    keep="last")

# %%
# Agrupar os dados por continente
continent = last_date.groupby(
    "continent")

# %%
# Somar os valores da coluna total_deaths para cada grupo
deaths_continent = continent["total_deaths"].sum()

# %%
# Resultado do número de mortes por continente, em ordem crescente.

print(deaths_continent.sort_values(ascending=False))
# Out:
# continent
# Asia             941547.0
# South America    930486.0
# Europe           770336.0
# North America    464649.0
# Africa           258841.0
# Oceania            4792.0
# Name: total_deaths, dtype: float64

# %% [markdown]
# O continente com maior número de mortes foi a Ásia, seguida pela América do Sul, Europa, América do Norte, África e Oceania.

# %% [markdown]
# ### 5 - Mostre o gráfico para a tabela criada na análise anterior.

# %%
#Tabela com os valores ordenados, para o gráfico ficar mais visual.
deaths_continent_sorted = deaths_continent.sort_values(ascending=False)

# %%
#Criar o gráfico de barras com os eixos número de mortes (Y) e continente (X).
plt.bar(deaths_continent_sorted.index, deaths_continent_sorted.values)
plt.title("Total de mortes por Covid por continente")
plt.xlabel("Continente")
plt.ylabel("Mortes")
plt.show()

# %% [markdown]
# Comparação dos resultados:
